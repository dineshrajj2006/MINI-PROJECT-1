# %% [markdown]
# #TABLE 1 : TEAMS

# %%
import requests
url = "https://api-web.nhle.com/v1/standings/now"
response = requests.get(url)
data = response.json()
data
# Out:
# {'wildCardIndicator': True,
#  'standingsDateTimeUtc': '2026-09-08T10:43:30Z',
#  'standings': [{'clinchIndicator': 'p',
#    'conferenceAbbrev': 'W',
#    'conferenceHomeSequence': 1,
#    'conferenceL10Sequence': 2,
#    'conferenceName': 'Western',
#    'conferenceRoadSequence': 1,
#    'conferenceSequence': 1,
#    'date': '2026-04-17',
#    'divisionAbbrev': 'C',
#    'divisionHomeSequence': 1,
#    'divisionL10Sequence': 1,
#    'divisionName': 'Central',
#    'divisionRoadSequence': 1,
#    'divisionSequence': 1,
#    'gameTypeId': 2,
#    'gamesPlayed': 82,
#    'goalDifferential': 99,
#    'goalDifferentialPctg': 1.207317,
#    'goalAgainst': 203,
#    'goalFor': 302,
#    'goalsForPctg': 3.682927,
#    'homeGamesPlayed': 41,
#    'homeGoalDifferential': 49,
#    'homeGoalsAgainst': 108,
#    'homeGoalsFor': 157,
#    'homeLosses': 9,
#    'homeOtLosses': 6,
#    'homePoints': 58,
#    'homeRegulationPlusOtWins': 25,
#    'homeRegulationWins': 25,
#    'homeTies': 0,
# ...

# %%
team_abbrev=data['standings'][0]['teamAbbrev']['default']
team_name=data['standings'][0]['teamName']['default']
conference_name=data['standings'][0]['conferenceName']
division_name=data['standings'][0]['divisionName']
logo_url=data['standings'][0]['teamLogo']

# %%
records = []
for team in data['standings']:
        records.append({
         'division_name': team['divisionName'],
         'conference_name': team['conferenceName'],
         'team_name': team['teamName']['default'],
         'team_abbrev': team['teamAbbrev']['default'],
         'logo_url': team['teamLogo']
     })
records
# Out:
# [{'division_name': 'Central',
#   'conference_name': 'Western',
#   'team_name': 'Colorado Avalanche',
#   'team_abbrev': 'COL',
#   'logo_url': 'https://assets.nhle.com/logos/nhl/svg/COL_light.svg'},
#  {'division_name': 'Metropolitan',
#   'conference_name': 'Eastern',
#   'team_name': 'Carolina Hurricanes',
#   'team_abbrev': 'CAR',
#   'logo_url': 'https://assets.nhle.com/logos/nhl/svg/CAR_light.svg'},
#  {'division_name': 'Central',
#   'conference_name': 'Western',
#   'team_name': 'Dallas Stars',
#   'team_abbrev': 'DAL',
#   'logo_url': 'https://assets.nhle.com/logos/nhl/svg/DAL_light.svg'},
#  {'division_name': 'Atlantic',
#   'conference_name': 'Eastern',
#   'team_name': 'Buffalo Sabres',
#   'team_abbrev': 'BUF',
#   'logo_url': 'https://assets.nhle.com/logos/nhl/svg/BUF_light.svg'},
#  {'division_name': 'Atlantic',
#   'conference_name': 'Eastern',
#   'team_name': 'Tampa Bay Lightning',
#   'team_abbrev': 'TBL',
# ...

# %%
import pymysql
conn=pymysql.connect(host='localhost',
                     user='root',
                     password='13849#Datasci',
                     database='proj1'
                     )
cursor=conn.cursor()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS teams (
    team_id INT AUTO_INCREMENT PRIMARY KEY,
    team_abbrev VARCHAR(10) UNIQUE,
    team_name VARCHAR(100),
    conference_name VARCHAR(100),
    division_name VARCHAR(100),
    logo_url TEXT
)

""")

conn.commit()

# %%
INSERT_QUERY = """
INSERT IGNORE INTO teams
(team_abbrev, team_name, conference_name, division_name, logo_url)
VALUES (%s, %s, %s, %s, %s)
"""

# %%
for i in records:
    
    values = (
        i['team_abbrev'],
        i['team_name'],
        i['conference_name'],
        i['division_name'],
        i['logo_url']
    )

    cursor.execute(INSERT_QUERY, values)

conn.commit()
cursor.execute("SELECT * FROM teams")
rows = cursor.fetchall()

# %%
import pandas as pd
df=pd.read_sql_query("select * from teams",conn)
df
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_20440\3301588069.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("select * from teams",conn)
#     team_id team_abbrev              team_name     conference_name  \
# 0         1     Central                Western  Colorado Avalanche
# 1         3         COL     Colorado Avalanche             Western
# 2         4         CAR    Carolina Hurricanes             Eastern
# 3         5         DAL           Dallas Stars             Western
# 4         6         BUF         Buffalo Sabres             Eastern
# 5         7         TBL    Tampa Bay Lightning             Eastern
# 6         8         MTL     Montréal Canadiens             Eastern
# 7         9         MIN         Minnesota Wild             Western
# ...

# %%
# TABLE 2: STANDINGS

# %%
import requests
url = "https://api-web.nhle.com/v1/standings/now"
response = requests.get(url)
data = response.json()
data
# Out:
# {'wildCardIndicator': True,
#  'standingsDateTimeUtc': '2026-09-06T15:35:46Z',
#  'standings': [{'clinchIndicator': 'p',
#    'conferenceAbbrev': 'W',
#    'conferenceHomeSequence': 1,
#    'conferenceL10Sequence': 2,
#    'conferenceName': 'Western',
#    'conferenceRoadSequence': 1,
#    'conferenceSequence': 1,
#    'date': '2026-04-17',
#    'divisionAbbrev': 'C',
#    'divisionHomeSequence': 1,
#    'divisionL10Sequence': 1,
#    'divisionName': 'Central',
#    'divisionRoadSequence': 1,
#    'divisionSequence': 1,
#    'gameTypeId': 2,
#    'gamesPlayed': 82,
#    'goalDifferential': 99,
#    'goalDifferentialPctg': 1.207317,
#    'goalAgainst': 203,
#    'goalFor': 302,
#    'goalsForPctg': 3.682927,
#    'homeGamesPlayed': 41,
#    'homeGoalDifferential': 49,
#    'homeGoalsAgainst': 108,
#    'homeGoalsFor': 157,
#    'homeLosses': 9,
#    'homeOtLosses': 6,
#    'homePoints': 58,
#    'homeRegulationPlusOtWins': 25,
#    'homeRegulationWins': 25,
#    'homeTies': 0,
# ...

# %%
data['standings'][0]
# Out:
# {'clinchIndicator': 'p',
#  'conferenceAbbrev': 'W',
#  'conferenceHomeSequence': 1,
#  'conferenceL10Sequence': 2,
#  'conferenceName': 'Western',
#  'conferenceRoadSequence': 1,
#  'conferenceSequence': 1,
#  'date': '2026-04-17',
#  'divisionAbbrev': 'C',
#  'divisionHomeSequence': 1,
#  'divisionL10Sequence': 1,
#  'divisionName': 'Central',
#  'divisionRoadSequence': 1,
#  'divisionSequence': 1,
#  'gameTypeId': 2,
#  'gamesPlayed': 82,
#  'goalDifferential': 99,
#  'goalDifferentialPctg': 1.207317,
#  'goalAgainst': 203,
#  'goalFor': 302,
#  'goalsForPctg': 3.682927,
#  'homeGamesPlayed': 41,
#  'homeGoalDifferential': 49,
#  'homeGoalsAgainst': 108,
#  'homeGoalsFor': 157,
#  'homeLosses': 9,
#  'homeOtLosses': 6,
#  'homePoints': 58,
#  'homeRegulationPlusOtWins': 25,
#  'homeRegulationWins': 25,
#  'homeTies': 0,
#  'homeWins': 26,
#  'l10GamesPlayed': 10,
#  'l10GoalDifferential': 14,
#  'l10GoalsAgainst': 20,
#  'l10GoalsFor': 34,
#  'l10Losses': 2,
#  'l10OtLosses': 1,
# ...

# %%
games_played = data['standings'][0]['gamesPlayed']
wins = data['standings'][0]['wins']
losses = data['standings'][0]['losses']
ot_losses = data['standings'][0]['otLosses']
points = data['standings'][0]['points']
goals_for = data['standings'][0]['goalFor']
goals_against = data['standings'][0]['goalAgainst']
home_wins = data['standings'][0]['homeWins']
away_wins = data['standings'][0]['roadWins']
streak_type = data['standings'][0]['streakCode']
streak_count = data['standings'][0]['streakCount']

# %%
records = []

season = "20252026"

for team in data['standings']:
    records.append({
        'season': season,
        'games_played': team['gamesPlayed'],
        'wins': team['wins'],
        'losses': team['losses'],
        'ot_losses': team['otLosses'],
        'points': team['points'],
        'goals_for': team['goalFor'],
        'goals_against': team['goalAgainst'],
        'home_wins': team['homeWins'],
        'away_wins': team['roadWins'],
        'streak_type': team['streakCode'],
        'streak_count': team['streakCount']
    })

# %%
import pymysql
conn=pymysql.connect(host='localhost',
                     user='root',
                     password='13849#Datasci',
                     database='proj1'
                     )
cursor=conn.cursor()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS standings (
    standing_id INT AUTO_INCREMENT PRIMARY KEY,
    team_id INT AUTO_INCREMENT PRIMARY KEY,
    season VARCHAR(20),
    games_played INT,
    wins INT,
    losses INT,
    ot_losses INT,
    points INT,
    goals_for INT,
    goals_against INT,
    home_wins INT,
    away_wins INT,
    streak_type VARCHAR(20),
    streak_count INT,
    FOREIGN KEY (team_id) REFERENCES teams(team_id)
)
""")

conn.commit()

# %%
INSERT_QUERY = """
INSERT INTO standings
(
    team_id,
    season,
    games_played,
    wins,
    losses,
    ot_losses,
    points,
    goals_for,
    goals_against,
    home_wins,
    away_wins,
    streak_type,
    streak_count
)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
for i in records:
    
    values = (
        i['team_id'],
        i['season'],
        i['games_played'],
        i['wins'],
        i['losses'],
        i['ot_losses'],
        i['points'],
        i['goals_for'],
        i['goals_against'],
        i['home_wins'],
        i['away_wins'],
        i['streak_type'],
        i['streak_count']
    )

    cursor.execute(INSERT_QUERY, values)

conn.commit()

# %%
cursor.execute("SELECT * FROM standings")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 3, '20252026', 82, 55, 16, 11, 121, 302, 203, 26, 29, 'W', 3)
# (2, 4, '20252026', 82, 53, 22, 7, 113, 296, 240, 29, 24, 'W', 1)
# (3, 5, '20252026', 82, 50, 20, 12, 112, 279, 226, 26, 24, 'W', 5)
# (4, 6, '20252026', 82, 50, 23, 9, 109, 288, 241, 26, 24, 'OT', 1)
# (5, 7, '20252026', 82, 50, 26, 6, 106, 290, 231, 26, 24, 'L', 1)
# (6, 8, '20252026', 82, 48, 24, 10, 106, 283, 256, 24, 24, 'L', 1)
# (7, 9, '20252026', 82, 46, 24, 12, 104, 272, 240, 23, 23, 'W', 1)
# (8, 10, '20252026', 82, 45, 27, 10, 100, 272, 250, 29, 16, 'W', 2)
# (9, 11, '20252026', 82, 44, 27, 11, 99, 278, 246, 23, 21, 'W', 1)
# (10, 12, '20252026', 82, 41, 25, 16, 98, 293, 268, 20, 21, 'L', 3)
# (11, 13, '20252026', 82, 43, 27, 12, 98, 250, 243, 20, 23, 'W', 3)
# (12, 14, '20252026', 82, 43, 30, 9, 95, 263, 244, 25, 18, 'W', 4)
# (13, 15, '20252026', 82, 39, 26, 17, 95, 265, 250, 20, 19, 'W', 3)
# (14, 16, '20252026', 82, 41, 30, 11, 93, 282, 269, 22, 19, 'W', 1)
# ...

# %%
print(data['standings'][0].keys())
# Out:
# dict_keys(['clinchIndicator', 'conferenceAbbrev', 'conferenceHomeSequence', 'conferenceL10Sequence', 'conferenceName', 'conferenceRoadSequence', 'conferenceSequence', 'date', 'divisionAbbrev', 'divisionHomeSequence', 'divisionL10Sequence', 'divisionName', 'divisionRoadSequence', 'divisionSequence', 'gameTypeId', 'gamesPlayed', 'goalDifferential', 'goalDifferentialPctg', 'goalAgainst', 'goalFor', 'goalsForPctg', 'homeGamesPlayed', 'homeGoalDifferential', 'homeGoalsAgainst', 'homeGoalsFor', 'homeLosses', 'homeOtLosses', 'homePoints', 'homeRegulationPlusOtWins', 'homeRegulationWins', 'homeTies', 'homeWins', 'l10GamesPlayed', 'l10GoalDifferential', 'l10GoalsAgainst', 'l10GoalsFor', 'l10Losses', 'l10OtLosses', 'l10Points', 'l10RegulationPlusOtWins', 'l10RegulationWins', 'l10Ties', 'l10Wins', 'leagueHomeSequence', 'leagueL10Sequence', 'leagueRoadSequence', 'leagueSequence', 'losses', 'otLosses', 'placeName', 'pointPctg', 'points', 'regulationPlusOtWinPctg', 'regulationPlusOtWins', 'regulat
# ...

# %%
import pandas as pd
df=pd.read_sql_query("select * from standings",conn)
df
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_25116\2434006533.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("select * from standings",conn)
#     standing_id  team_id    season  games_played  wins  losses  ot_losses  \
# 0             1        3  20252026            82    55      16         11
# 1             2        4  20252026            82    53      22          7
# 2             3        5  20252026            82    50      20         12
# 3             4        6  20252026            82    50      23          9
# 4             5        7  20252026            82    50      26          6
# 5             6        8  20252026            82    48      24         10
# 6             7        9  20252026            82    46      24         12
# ...

# %%
#TABLE 3 : PLAYERS

# %%
# Out:
# 200
# dict_keys(['forwards', 'defensemen', 'goalies'])

# %%
import pymysql

conn = pymysql.connect(
    host="localhost",
    user="root",
    password="13849#Datasci",
    database="proj1"
)

cursor = conn.cursor()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS players (
    player_id BIGINT PRIMARY KEY,
    team_id INT,
    first_name VARCHAR(100),
    last_name VARCHAR(100),
    position VARCHAR(10),
    jersey_number INT,
    birth_date DATE,
    birth_country VARCHAR(10),
    height_cm REAL,
    weight_kg REAL,
    shoots_catches VARCHAR(5),
    headshot_url TEXT,
    FOREIGN KEY (team_id) REFERENCES teams(team_id)

)
""")

conn.commit()

# %%
cursor.execute("""
SELECT team_id, team_abbrev
FROM teams
""")

teams = cursor.fetchall()

# %%
team_lookup = { team_abbrev: team_id
    for team_id, team_abbrev in cursor.fetchall()
}

# %%
import requests
for team_abbrev, team_id in team_lookup.items(): 
    url = f"https://api-web.nhle.com/v1/roster/{team_abbrev}/current"
    response = requests.get(url)
    print("Team:", team_abbrev)
    for group in ("forwards", "defensemen", "goalies"):
        for player in data.get(group, []):
            values = (
                player['id'],
                team_id,
                player['firstName']['default'],
                player['lastName']['default'],
                player.get('positionCode'),
                player.get('sweaterNumber'),
                player.get('birthDate'),
                player.get('birthCountry'),
                player.get('heightInCentimeters'),
                player.get('weightInKilograms'),
                player.get('shootsCatches'),
                player.get('headshot')
            )

            print(values)
# Out:
# Team: ANA
# (8483804, 20, 'Riley', 'Bezeau', 'R', None, '2002-05-04', 'USA', 183, 85, 'R', 'https://assets.nhle.com/mugs/nhl/20262027/CBJ/8483804.png')
# (8475745, 20, 'Charlie', 'Coyle', 'C', 3, '1992-03-02', 'USA', 191, 100, 'R', 'https://assets.nhle.com/mugs/nhl/20262027/CBJ/8475745.png')
# (8483432, 20, 'Luca', 'Del Bel Belluz', 'C', 93, '2003-11-10', 'CAN', 185, 84, 'L', 'https://assets.nhle.com/mugs/nhl/20262027/CBJ/8483432.png')
# (8483688, 20, 'Jordan', 'Dumais', 'R', 22, '2004-04-15', 'CAN', 173, 78, 'R', 'https://assets.nhle.com/mugs/nhl/20262027/CBJ/8483688.png')
# (8486173, 20, 'Josh', 'Eernisse', 'C', None, '2001-12-31', 'USA', 191, 98, None, 'https://assets.nhle.com/mugs/nhl/20262027/CBJ/8486173.png')
# (8478856, 20, 'Conor', 'Garland', 'R', 83, '1996-03-11', 'USA', 178, 75, 'R', 'https://assets.nhle.com/mugs/nhl/20262027/CBJ/8478856.png')
# ...

# %%
INSERT_QUERY = """
INSERT INTO players
(
    player_id,
    team_id,
    first_name,
    last_name,
    position,
    jersey_number,
    birth_date,
    birth_country,
    height_cm,
    weight_kg,
    shoots_catches,
    headshot_url
)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
conn.commit()
cursor.execute("SELECT * FROM players")
records = cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 conn.commit()
#       2 cursor.execute("SELECT * FROM players")
#       3 records = cursor.fetchall()
#
# NameError: name 'conn' is not defined

# %%
import pandas as pd

# %%
df=pd.read_sql_query("select * from players",conn)
df
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_17228\2669807433.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("select * from players",conn)
#      player_id  team_id first_name    last_name position  jersey_number  \
# 0      8473533        4     Jordan        Staal        C           11.0
# 1      8473986       20       Alex      Killorn        L           17.0
# 2      8475184       20      Chris      Kreider        L           20.0
# 3      8475235        4    Nicolas  Deslauriers        L           44.0
# 4      8475324       20       Nick       Jensen        D            4.0
# ..         ...      ...        ...          ...      ...            ...
# 207    8486052       20     Nikita       Klepov        R           40.0
# 208    8486072       20     Marcus     Nordmark        L           43.0
# ...

# %% [markdown]
#  TABLE 4 : GAMES

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS games (
    game_id BIGINT PRIMARY KEY,
    season VARCHAR(20),
    game_type INT,
    game_date DATE,
    home_team_id INT,
    away_team_id INT,
    home_score INT,
    away_score INT,
    game_state VARCHAR(20),
    venue_name VARCHAR(150),

    FOREIGN KEY (home_team_id) REFERENCES teams(team_id),
    FOREIGN KEY (away_team_id) REFERENCES teams(team_id)
)
""")
conn.commit()

# %%
cursor.execute("SELECT team_id, team_abbrev FROM teams")
teams = cursor.fetchall()

# %%
team_lookup = {}
for team_id, team_abbrev in teams:
    team_lookup[team_abbrev] = team_id

# %%
team_lookup
# Out:
# {'ANA': 20,
#  'BOS': 10,
#  'BUF': 6,
#  'CAR': 4,
#  'CBJ': 19,
#  'Central': 1,
#  'CGY': 31,
#  'CHI': 33,
#  'COL': 3,
#  'DAL': 5,
#  'DET': 18,
#  'EDM': 16,
#  'FLA': 27,
#  'LAK': 22,
#  'MIN': 9,
#  'MTL': 8,
#  'NJD': 23,
#  'NSH': 25,
#  'NYI': 21,
#  'NYR': 32,
#  'OTT': 11,
#  'PHI': 13,
#  'PIT': 12,
#  'SEA': 29,
#  'SJS': 26,
#  'STL': 24,
#  'TBL': 7,
#  'TOR': 30,
#  'UTA': 17,
#  'VAN': 34,
#  'VGK': 15,
#  'WPG': 28,
#  'WSH': 14}

# %%
import requests

INSERT_QUERY = """
INSERT IGNORE INTO games
(
    game_id,
    season,
    game_type,
    game_date,
    home_team_id,
    away_team_id,
    home_score,
    away_score,
    game_state,
    venue_name
)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

for team_abbrev, team_id in team_lookup.items():
    url = f"https://api-web.nhle.com/v1/club-schedule-season/{team_abbrev}/20252026"
    response = requests.get(url)
    print(team_abbrev, response.status_code)
    if response.status_code != 200:
        print("API Error:", response.text)
        continue
    data = response.json()
    for game in data.get("games", []):
        values = (
            game["id"],
            game["season"],
            game["gameType"],
            game["gameDate"],
            game["homeTeam"]["id"],
            game["awayTeam"]["id"],
            game["homeTeam"].get("score"),
            game["awayTeam"].get("score"),
            game.get("gameState"),
            game.get("venue", {}).get("default")
        )

        cursor.execute(INSERT_QUERY, values)

conn.commit()
# Out:
# ANA 200
# BOS 200
# BUF 200
# CAR 200
# CBJ 200
# Central 404
# API Error: <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html;charset=ISO-8859-1"/>
# <title>Error 404 Not Found</title>
# </head>
# <body>
# <h2>HTTP ERROR 404 Not Found</h2>
# <table>
# <tr><th>URI:</th><td>https://api-web.nhle.com/v1/club-schedule-season/Central/20252026</td></tr>
# <tr><th>STATUS:</th><td>404</td></tr>
# <tr><th>MESSAGE:</th><td>Not Found</td></tr>
# </table>
#
# </body>
# </html>
#
# CGY 200
# CHI 200
# COL 200
# DAL 200
# DET 200
# EDM 200
# FLA 200
# LAK 200
# MIN 200
# MTL 200
# NJD 200
# NSH 200
# NYI 200
# NYR 200
# OTT 200
# PHI 200
# PIT 200
# SEA 200
# SJS 200
# STL 200
# TBL 200
# TOR 200
# UTA 200
# VAN 200
# VGK 200
# WPG 200
# WSH 200
# Games inserted successfully

# %%
cursor.execute("SELECT * FROM games")
records = cursor.fetchall()

# %%
import pandas as pd
df=pd.read_sql_query("select * from games",conn)
df
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_2492\2402511479.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("select * from games",conn)
#          game_id    season  game_type   game_date  home_team_id  away_team_id  \
# 0     2025010001  20252026          1  2025-09-21            26            24
# 1     2025010002  20252026          1  2025-09-21            22            20
# 2     2025010003  20252026          1  2025-09-21            20            22
# 3     2025010004  20252026          1  2025-09-21            18            13
# 4     2025010005  20252026          1  2025-09-21            18            13
# ...          ...       ...        ...         ...           ...           ...
# 1057  2025030311  20252026          3  2026-05-21            12             8
# ...

# %%
# TABLE  5: GAME STATS

# %%
df_games=pd.read_json('game_stats.json')
df_games
# Out:
#        stat_id     game_id  player_id  team_id  goals  assists  points  \
# 0            1  2025010051    8480448        1      0        0       0
# 1            2  2025010051    8479525        1      0        0       0
# 2            3  2025010051    8477492        1      0        1       1
# 3            6  2025010051    8477476        1      1        1       2
# 4           10  2025010051    8482947        1      1        0       1
# ...        ...         ...        ...      ...    ...      ...     ...
# 47403    53923  2025021300    8476879       20      0        0       0
# 47404    53924  2025021300    8476441       20      0        0       0
# 47405    53925  2025021300    8474563       20      0        1       1
# 47406    53926  2025021300    8479998       20      0        0       0
# 47407    53927  2025021300    8482730       20      0        0       0
#
#        shots_on_goal  penalty_min    toi  plus_minus
# 0                  0            0  14:28           0
# ...

# %%
import pymysql
from sqlalchemy import create_engine
engine = create_engine(
    "mysql+pymysql://root:13849#Datasci@localhost/proj1"
)

# %%
df_games.to_sql('game_stats',if_exists='replace',con=engine)
# Out:
# 47408

# %% [markdown]
# # TABLE 6 :  skater_season_stats

# %%
df_games=pd.read_json('skater_season_stats.json')
df_games
# Out:
#      stat_id  player_id    season  team_id  games_played  goals  assists  \
# 0          1    8470613  20252026        1          82.0   12.0     23.0
# 1          2    8475172  20252026        1          77.0   16.0     34.0
# 2          3    8475754  20252026        1          81.0   33.0     32.0
# 3          4    8475768  20252026        1          50.0   11.0     15.0
# 4          5    8476312  20252026        1          79.0    5.0     26.0
# ..       ...        ...       ...      ...           ...    ...      ...
# 709      710    8483678  20252026       32          70.0    3.0      7.0
# 710      711    8483768  20252026       32          24.0    0.0      3.0
# 711      712    8484136  20252026       32          66.0   13.0      6.0
# 712      713    8484240  20252026       32          70.0    5.0     16.0
# 713      714    8484798  20252026       32          76.0    6.0     20.0
#
#      points  plus_minus  penalty_min  shots  avg_toi
# ...

# %%
df_games.to_sql('skater_season_stats',if_exists='replace',con=engine)
# Out:
# 714

# %%
#Table 7: goalie_season_stats

# %%
df_games=pd.read_json('goalie_season_stats.json')
df_games
# Out:
#     stat_id  player_id    season  team_id  games_played  wins  losses  \
# 0         1    8475809  20252026        1          45.0  31.0     6.0
# 1         2    8478406  20252026        1          39.0  23.0    10.0
# 2         3    8481611  20252026        2           9.0   6.0     2.0
# 3         4    8483548  20252026        2          39.0  31.0     6.0
# 4         5    8479193  20252026        3          30.0  15.0     8.0
# ..      ...        ...       ...      ...           ...   ...     ...
# 76       77    8481519  20252026       31          55.0  19.0    25.0
# 77       78    8482821  20252026       31          26.0   8.0    13.0
# 78       79    8477967  20252026       32          20.0   8.0    10.0
# 79       80    8480947  20252026       32          47.0  11.0    27.0
# 80       81    8484268  20252026       32          21.0   6.0    11.0
#
#     ot_losses  save_pct  goals_against_avg  shutouts  saves
# 0         6.0  0.921317                NaN       4.0    NaN
# ...

# %%
df_games.to_sql(' goalie_season_stats',if_exists='replace',con=engine)
# Out:
# 81
